# %% [markdown]
# <a href="https://colab.research.google.com/github/r357/EconLab-GPT-Beer/blob/master/GPT2_Biden.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
gpt2.download_gpt2(model_name="124M")
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/realdonaldtrump_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/kanyewest_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/joebiden_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/elonmusk_tweets.csv -q
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Fetching checkpoint: 1.05Mit [00:00, 380Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 80.5Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 281Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:07, 64.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 420Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 135Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 142Mit/s]

# %%
ind = 3

# %tensorflow_version 1.x
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

file_names = ["realdonaldtrump_tweets.csv",
              "elonmusk_tweets.csv",
              "kanyewest_tweets.csv",
              "joebiden_tweets.csv"]

sess = gpt2.start_tf_sess()

run = file_names[ind].split("_")[0]

gpt2.finetune(sess,
              dataset=file_names[ind],
              model_name='124M',
              steps=150,
              restore_from='fresh',
              run_name=run,
              save_every=150,
              print_every=10)
              #sample_every=200,
              #save_every=1
              #)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00, 16.06it/s]
# Loading dataset...
# dataset has 560735 tokens
# Training...
# [10 | 52.81] loss=1.97 avg=1.97
# [20 | 98.50] loss=2.08 avg=2.03
# [30 | 144.21] loss=1.95 avg=2.00
# [40 | 189.87] loss=1.67 avg=1.92
# [50 | 235.57] loss=1.76 avg=1.88
# [60 | 281.26] loss=1.86 avg=1.88
# [70 | 326.92] loss=1.67 avg=1.85
# [80 | 372.59] loss=1.81 avg=1.84
# [90 | 418.31] loss=1.59 avg=1.81
# [100 | 464.03] loss=1.64 avg=1.80
# ======== SAMPLE 1 ========
#  Trump in the Oval Office:<|endoftext|>
# <|startoftext|>The Democrats are dead wrong on climate change. If they did, we'd be stronger in our fight — and stronger in bringing about real change here in the U.S.:<|endoftext|>
# <|startoftext|>Climate change is impacting every family, every place, every day. And as president, I'll protect his presidency to the last person able to stand up and demand action.<|endoftext|>
# <|startoftext|>Let’s be clear: I know climate change is a global threat and that every life is on the line. What's the harm in talking to children? What’s the harm in pandemics? And what's the harm in pandering to the Trump base?<|endoftext|>
# <|startoftext|>The GOP may not be as focused on climate change as it once was. But they are not as far-sighted today as they were eight decades ago.<|endoftext|>
# <|startoftext|>The Democratic Party and their supporters continue to be the ones that beat Donald Trump. We cannot afford another coronavirus.
#
# I'll take the fight to him - he'll make sure the American people are not so safe.<|endoftext|>
# <|startoftext|>The way we deal with this pandemic is by addressing the root causes — not just pandemics. I'm about to deliver a keynote at the Democratic Leadership Forum on Sunday.<|endoftext|>
# <|startoftext|>Donald Trump and the Democratic Party are on the frontlines of the global fight against climate change. Their greed is poison to our health and our future. They have abandoned middle class Americans and failed to serve our workers.<|endoftext|>
# <|startoftext|>We can't go on like this and get our promises up and running again. We need to find the strength to do so. This time, I'm going to do it with science.<|endoftext|>
# <|startoftext|>This is not a coronavirus. I will never accept something that's so close to an individual's heart, or the courage of others.
#
# He is an American patriot, and I will make him a one-term president.<|endoftext|>
# <|startoftext|>This president wants to double down on the attacks against North Korea—which threaten our national security, and we need to defend ourselves on the world stage.<|endoftext|>
# <|startoftext|>I’ve said it from the get-go: I’m not afraid to take a gamble.
#
# My heart still beats on the White House in the face of Donald Trump and the threat of climate change. We can't let that scare us away.<|endoftext|>
# <|startoftext|>The President has made a big bet on Donald Trump: he’s the one who will run for president. But for the first time, has he ever said, "You are expendable—you have to get the job done."
#
# Donald Trump must be prepared at all times to deal with this new threat and meet it.<|endoftext|>
# <|startoftext|>We have to get Donald Trump out of the White House because we can’t get him back. #CivAction<|endoftext|>
# <|startoftext|>Thank you to the Democratic Congressional Campaign Committee for your steady work attacking Donald Trump and supporting our campaign. Your dedication to the fight for economic justice and fairness is unparalleled. Thanks to all of our folks working tirelessly to ensure this never happens again.<|endoftext|>
# <|startoftext|>I was inspired to launch this campaign with your contributions to support a president who will fight against it.<|endoftext|>
# <|startoftext|>I’m honored by all the hard work you did for us—and the support you give means the world to us. I promise you'll always be a part of our movement — and that will never change if we do it together.<|endoftext|>
# <|startoftext|>The Obama-Biden Administration made it clear to North Korean dictator Kim Jong Un that it believed he needed special treatment in return for his successful nuclear test. President Trump claimed that it was an abuse of power, but it could be seen as an honest mistake—and he has yet to reverse it.<|endoftext|>
# <|startoftext|>Donald Trump is in a battle for the soul of this country—first and foremost with North Korea. He must stop this now.<|endoftext|>
# <|startof
#
# [110 | 528.03] loss=1.50 avg=1.77
# [120 | 573.68] loss=1.59 avg=1.75
# [130 | 619.36] loss=1.65 avg=1.74
# [140 | 665.07] loss=1.46 avg=1.72
# [150 | 710.84] loss=1.45 avg=1.70
# Saving checkpoint/joebiden/model-150

# %%
prefixes = ["EconLab beer is",
            "This beer makes me",
            "I'd never say this about a beer, but",
            "EconLab's beer tastes like",
            "Beer.",
            "This beer will make you want to",
            "This beer is",
            "This beer is just"]

# %%
for prefix in prefixes:
    print()
    gpt2.generate(sess,
                  run_name=run,
                  length=200,
                  temperature=0.7,
                  prefix=prefix,
                  nsamples=10,
                  truncate='<|endoftext|>'
                  )
# Out:
# EconLab beer is the best in the industry.” —Joe
# ====================
# EconLab beer is in great hands, and I commend the farmers on their progress. But the farmers on the front lines of this fight deserve better.
#
# Chip in to help fuel our fight for fair wages and fair work conditions:
# ====================
# EconLab beer is the best I've ever had... #UAW42 #TeamJoe
# ====================
# EconLab beer is one of those things that is on my mind every day, and I'm proud to announce it's on my’s way out of the White House. #ABaldeen
#
# I’m proud to stand with @HansPerez and @BarackObama and all those who have fought and passed the Affordable Care Act. Each of us is entitled to our own freedom, and each of us has a dignified place in the world at large.
# ====================
# EconLab beer is one of the finest, boldest, most impressive, and most wonderful craft beers on the planet. And I think it's time we hold the @IBU on account.
#
# If we stand together, we've got to get it done.
#
# Join us:
# ====================
# EconLab beer is the best, most flavorful, and most affordable way to get out the vote. It works — folks vote early.
#
# Iowa voters, please vote early.
# ====================
# EconLab beer is part of our mission, and to this day we are proud to have the support of @OECD. We cannot rest until we achieve a 21st-century energy security and a 21st-century clean energy economy.
# ====================
# EconLab beer is made in our own house. We're not dependent on foreign companies — we're looking at our own history and our own interests.” —VP Biden #BeABarBiden
# ====================
# EconLab beer is a celebration of the work of generations, honoring the memory of our brave soldiers and our indomitable spirit. We need to get to work on day one to ensure every American has access to quality, affordable health care.
# ====================
# EconLab beer is better than nothing. We're going to fight tooth and nail to keep it.
# ====================
#
# This beer makes me want to throw up."
#
# We'll keep you in the loop as we share our stories. We'll keep you in the loop as we share our stories.
#
# The tough truth is this: we shouldn't have to build an entire generation of CEOs who promise to restore the soul of this nation—but instead, we shouldn't have to build our way back through this crisis.
#
# Chip in to keep our momentum going:
# ====================
# This beer makes me sick to my stomach. It’s wrong.
# ====================
# This beer makes me gash over the death of Michael Brown’s family and feels like home to me. I’m proud & grateful for the support of @TeamJoe, @BidenDSM, @BlackLivesMatter, @TeamJoe, @BeauBiden, @TeamJoe, @TeamJoe, @TeamJoe, @TeamJoe, @TeamJoe, @TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, #TeamJoe, [via @TeamJoe]
# <|startoftext|>On the anniversary of the murder of our nation’s Attorney General, is it time we’re honoring the memory of those who lost their lives in service to our democracy?✝
# ====================
# This beer makes me want to go back to my neighborhood, and I want to use it to the maximum. #BeItOrange
# ====================
# This beer makes me happy. I hope you enjoyed it.
# ====================
# This beer makes me want to go back to drinking it every day. #ItsYourBitter
# ====================
# This beer makes me proud to be a part of the @NordicSpring Festival’s celebration of diversity and inclusion. @DrBiden and I are grateful to catch up and to thank you for your support. We want to hear from you, folks. Share what you're hearing—we're all on the wrong side of history.
# ====================
# This beer makes me want to choke. Like I've never been more determined to push forward and fight for what's right.
# ====================
# This beer makes me want to drink more!"<|startoftext|>I just got off the phone with @Colombia's President @EstaMoraSantos, where I asked him about his plan to strengthen our economy and build an inclusive middle class.
# ====================
# This beer makes me want to drink more.
#
# It's the only one I know of that doesn't contain a heavy H.I.Z. and/or a toxic H.I.Z. and/or a poisonous H.I.This is the definition of medicine.
# ====================
#
# I'd never say this about a beer, but I’ve seen it happen.
# ====================
# I'd never say this about a beer, but I'd say it about a whole lot of people. Lives are on the line every day.
# ====================
# I'd never say this about a beer, but I’ve never been more proud to have a partner who I can’t wait to call if I’m ready to talk about my bold vision for our country.
# ====================
# I'd never say this about a beer, but I would say it's about more than just a beer. It's about this country, this spirit, this diversity, this American spirit. And I believe we can bring together all of America to bring this great country, together. And that's why I’ll be in Philadelphia on @PeteButtigieg tonight to discuss how we can do that.
# ====================
# I'd never say this about a beer, but if you want to be a part of the fight for LGBTQ rights, you need to wear a mask.
# ====================
# I'd never say this about a beer, but I've seen it. A culture that has been built on corruption, on fear, on division. We have to stand up, fight back, and take back this country. That's what America is all about.
# ====================
# I'd never say this about a beer, but I wouldn't call it pep talk.”—VP Biden in #VA’s #DemDebate
# ====================
# I'd never say this about a beer, but I'm more proud of the Sioux City, Iowa, team." —VP Biden
# ====================
# I'd never say this about a beer, but it's hard not to get a kick out of my favorite American Indian food. That is what makes me proud to be a part of, and I hope you are too.
# ====================
# I'd never say this about a beer, but I ’m not surprised the #TakeItOutCock’s endorsement wasn’t enough.
# ====================
#
# EconLab's beer tastes like the stuff of legend. I think it's great to be back, but I couldn't say the same about the great talent on stage. Thank you to everyone who supported us and to the folks in the crowd who helped us reach our goal.
#
# Cheers, @KamalaHarrisABBL!
# ====================
# EconLab's beer tastes like nothing but bock. It's the only thing I've ever liked about this country. It's why I have the boldest vision for this country. And it's why I'm going to be the most pro-worker president in our history.
# ====================
# EconLab's beer tastes like nothing you can imagine.
#
# We're going to change the culture of L.A. County, and we're going to get it done—together.
# ====================
# EconLab's beer tastes like heaven #FTP #CinemaAmerica #OlympicsWings #PuertoBarrio #OrganizationofAction #FTP #CinemaAmerica #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #FTP #FTP #FTP #FTP #FTP #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #FTP #FTP #FTP #FTP #FTP #CinemaAmerica #FTP #FTP #FTP #FTP #FTP #FTP #FTP #FTP #EconLab's beer tastes like heaven #FTP #FTP #FTP #FTP #Cinema
# ====================
# EconLab's beer tastes like the stuff of Ryan & Co.:
# ====================
# EconLab's beer tastes like something out of Dante's story. “The story of America’s great war—the story of how we got to where we are.” Jill and I are deeply honored to have the opportunity to work alongside you to bring this great crusade to light and to make it a reality.
# ====================
# EconLab's beer tastes like yours. If you like Crooked Hillary, join us on Saturday, June 27th:
# ====================
# EconLab's beer tastes like nothing you've ever tried. #FUDgedBier👙t
# ====================
# EconLab's beer tastes like a treat for the people who make it.
# ====================
# EconLab's beer tastes like the finest of American ales. #AmericanAlesDay #AmericanAlesDay #AmericanAlesDay #AmericanAlesDay
#
# Voting is open until 3:30 PM ET! Head to   to make an account for your ballot.
# ====================
#
# Beer.biz
# ====================
# Beer.org
# ====================
# Beer.com/talkshow/the-young-job-reform-of-2012
# ====================
# Beer.
#
# We are all in this together.
# ====================
# Beer.
#
# Not just for themselves — but for all the folks around the world.
#
# Together, we're going to get this virus under control — and then let's get it done.
# ====================
# Beer.
#
# If you're looking for something different than what we have seen from our @realDonaldTrump @DrBiden supporters, check out our new #BidenInstagram account:
# ====================
# Beer.
#
# I don't care what your politics are, I care about your ideals and values.
#
# The choice is clear: Vote me out of office or get out of my way.
# ====================
# Beer.com/Premiums/M-Day
# ====================
# Beer. They may not be the best of friends, but they will always keep you company when it comes to the things you love about yourself and your family.
# ====================
# Beer.com
#
# Tell your friends about #AmericansFor21:
# ====================
#
# This beer will make you want to come back to the fight. And it will make you want to drink it again.
# ====================
# This beer will make you want to stop drinking!"
# ====================
# This beer will make you want to say thank you to everyone who came out to our town hall last night! Tune in for our town hall with @senatemajldr tonight at 5pm ET:
# ====================
# This beer will make you want to leave the hospital and get your COVID-19 tests done.
# ====================
# This beer will make you want to crawl, smile, and thank the angels for all the love, support, and encouragement you've been able to receive. I have seen it all. And I’m ready to get to work."
#
# <|startoftext|>I have a lot of respect for Mark Warner. He has provided a voice for our country in a way few others have ever been able to. His courage and vitriol are a reminder of everything we need to do to ensure Donald Trump is removed from the White House and re-elected.
#
# Join me in saying that we need to elect a president who will stand up to the abuse of power and hold Donald Trump accountable.
# ====================
# This beer will make you want to kick back, breathe a sigh of relief, and give your friends a smile.
#
# Weve got to do better.
# ====================
# This beer will make you want to go out and buy some ice cream."
#
# <|startoftext|>We need a leader who will lead us through this moment in time to make it clear that our shared commitments to climate justice and the most pressing threats to the future are real and urgent.
#
# Donald Trump is the wrong man to lead this country through this moment.
# ====================
# This beer will make you want to root for you and your neighbors. #WhipTheDog2
# ====================
# This beer will make you want to eat more.”—VP Biden in Ohio
# ====================
# This beer will make you want to go to the movies again.
#
# It will make you want to wear a mask.
# ====================
#
# This beer is more than just a statement of faith: It's about a commitment to change.” — Senator Warren and I will be joining @DrBiden tomorrow for a #OneYearSummit.
# ====================
# This beer is our heritage. And we're going to continue to fight for it. #TeamJoe
# ====================
# This beer is the finest, most complete, and most complete definition of the word. No other can compete.
# ====================
# This beer is great—it’s good for you, @TrevorandJoe. I know how to win and I will win alongside you.
# ====================
# This beer is our choice to be the most powerful force in our country.
#
# We must rebuild this nation of opportunity.
# ====================
# This beer is the definition of American craft beer. #CinematicEra
# ====================
# This beer is great! Thank you for having the opportunity to be part of the Great American Beer Festival.” —VP Biden in Cedar Rapids on the #GreatAmericanBight in 2014
# ====================
# This beer is never easy, and I promise it won't be anytime soon. I know the journey, and I promise you'll get through it. Thank you." —VP Biden
# ====================
# This beer is for folks who need help.”—VP Biden today at #BidenForPresident.
# ====================
# This beer is a reminder to everyone that we are all in this together and that we can overcome any challenges.”
#
# Joey’s message to @realDonaldTrump is clear: Don't take us for granted.
# ====================
#
# This beer is just a giant step up from what I have been able to accomplish in the last year.
# ====================
# This beer is just that: a good bet to get your hands on some early access. I've made sure that in the last few weeks, you can get yours today:
# ====================
# This beer is just plain good. Pigeon pie was good." —VP Biden on a PPE break in 2008
#
# “”
# “”
# “”
# “”
# ”Folks, we’re just getting started. We're going to make sure you get the best value for your money.”
# ====================
# This beer is just plain good and I'm looking forward to finding out how it will impact my life and career in the next 3 years.
# ====================
# This beer is just plain good. I can't wait to make sure everyone has a great trip to the Convention Center this fall.
# ====================
# This beer is just plain awesome!
# ====================
# This beer is just plain good. -Dr. Martin Luther King Jr."”
# ====================
# This beer is just plain awesome. So much of what makes me so happy that I’ve got a beer all over my head today.
# ====================
# This beer is just too good to deny."
#
# #FUTUREFACT — @JeffBiden and I are grateful to have a great first President.
# ====================
# This beer is just one of many so-called "local" beers on this list. We've seen greatness from Delaware, we've seen greatness from the best of America—and we've seen greatness from everything we stand for.
#
# Join us:
# ====================
