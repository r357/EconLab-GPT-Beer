# %% [markdown]
# <a href="https://colab.research.google.com/github/r357/EconLab-GPT-Beer/blob/master/Notebooks/GPT2_Freud2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
gpt2.download_gpt2(model_name="124M")
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/realdonaldtrump_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/kanyewest_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/joebiden_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/elonmusk_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/_karlmarxbot_tweets.csv -q
# !wget https://raw.githubusercontent.com/r357/EconLab-GPT-Beer/master/Tweets/SigmundFreud_SE_tweets.csv -q
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Fetching checkpoint: 1.05Mit [00:00, 274Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 66.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 277Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:02, 189Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 240Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 103Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 119Mit/s]

# %%
ind = 5

# %tensorflow_version 1.x
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

file_names = ["realdonaldtrump_tweets.csv",
              "elonmusk_tweets.csv",
              "kanyewest_tweets.csv",
              "joebiden_tweets.csv",
              "_karlmarxbot_tweets.csv",
              "SigmundFreud_SE_tweets.csv"]

sess = gpt2.start_tf_sess()

run = file_names[ind].split("_")[0]

gpt2.finetune(sess,
              dataset=file_names[ind],
              model_name='124M',
              steps=150,
              restore_from='fresh',
              run_name=run,
              save_every=150,
              print_every=10)
              #sample_every=200,
              #save_every=1
              #)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00,  8.84it/s]
# Loading dataset...
# dataset has 1218771 tokens
# Training...
# [10 | 49.98] loss=2.54 avg=2.54
# [20 | 93.17] loss=2.50 avg=2.52
# [30 | 136.77] loss=2.10 avg=2.38
# [40 | 180.52] loss=2.04 avg=2.29
# [50 | 224.36] loss=2.33 avg=2.30
# [60 | 268.23] loss=1.93 avg=2.24
# [70 | 312.13] loss=2.14 avg=2.22
# [80 | 356.07] loss=2.18 avg=2.22
# [90 | 399.95] loss=2.08 avg=2.20
# [100 | 443.87] loss=2.09 avg=2.19
# ======== SAMPLE 1 ========
# ...

# %%
prefixes = ["EconLab beer is",
            "This beer makes me",
            "I'd never say this about a beer, but",
            "EconLab's beer tastes like",
            "Beer.",
            "This beer will make you want to",
            "This beer is",
            "This beer is just"]

# %%
for prefix in prefixes:
    print()
    gpt2.generate(sess,
                  run_name=run,
                  length=200,
                  temperature=0.7,
                  prefix=prefix,
                  nsamples=10,
                  truncate='<|endoftext|>'
                  )
# Out:
# EconLab beer is the last one to learn of the origin of the psychical reactions to the bitter [cont.] {cont}
# ...
# EconLab beer is quite a revelation. This is a very interesting discovery, and just as I had first phoned you here, I now find that I am not alone. {cont}
# ...
# EconLab beer is a great substitute for the wine, and so on. (11, 183-184)
# ...
# EconLab beer is a general term for beer which is used by philosophers and philosophers alike for the being of something which is something, and in particular for {cont}
# ...
# EconLab beer is not a substitute for the ordinary choice (as I have already explained) of a variety of the same characteristics. (4, 105)
# ...
# EconLab beer is not a simple thing. The only differences are the characteristics of the two distillates; and the fact that the two distilleries produce different German expressions shows that these two distilleries have separate methods of making beer.
# ...
